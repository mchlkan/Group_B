# %%
from main import OwidData, WebApp
import pandas as pd
import streamlit as st
import geopandas as gpd
from pathlib import Path




obj = WebApp()

# %%
ann_cng = obj.datasets['Annual Change In Forest Area']
an_defo = obj.datasets['Annual Deforestation']
shr_prot = obj.datasets['Share Of Protected Land']
shr_deg = obj.datasets['Share Of Degraded Land']

# %%
ann_cng.shape
# Out:
# (5915, 12)

# %%
ann_cng.head()
# Out:
#                                             geometry         NAME  \
# 0  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  Afghanistan
# 1  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  Afghanistan
# 2  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  Afghanistan
# 3  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  Afghanistan
# 4  POLYGON ((66.51861 37.36278, 67.07578 37.35614...  Afghanistan
#
#     SOVEREIGNT CONTINENT REGION_UN      SUBREGION   REGION_WB  \
# 0  Afghanistan      Asia      Asia  Southern Asia  South Asia
# 1  Afghanistan      Asia      Asia  Southern Asia  South Asia
# 2  Afghanistan      Asia      Asia  Southern Asia  South Asia
# 3  Afghanistan      Asia      Asia  Southern Asia  South Asia
# 4  Afghanistan      Asia      Asia  Southern Asia  South Asia
#
#                      ECONOMY     INCOME_GRP  Annual Change In Forest Area  \
# 0  7. Least developed region  5. Low income                           0.0
# 1  7. Least developed region  5. Low income                           0.0
# 2  7. Least developed region  5. Low income                           0.0
# 3  7. Least developed region  5. Low income                           0.0
# 4  7. Least developed region  5. Low income                           0.0
#
#    year       entity
# 0  1991  Afghanistan
# 1  1992  Afghanistan
# 2  1993  Afghanistan
# 3  1994  Afghanistan
# 4  1995  Afghanistan

# %%
round(12.2048,2)
# Out:
# 12.2
