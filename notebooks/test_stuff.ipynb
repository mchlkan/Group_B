# %%
from main import OwidData
import pandas as pd
import streamlit as st
import geopandas as gpd
from pathlib import Path


obj = OwidData()

# %%
ann_cng = obj.datasets['Annual Change In Forest Area']
an_defo = obj.datasets['Annual Deforestation']
shr_prot = obj.datasets['Share Of Protected Land']
shr_deg = obj.datasets['Share Of Degraded Land']

# %%
ann_cng.head()
# Out:
#         entity code  year  net_change_forest_area
# 0  Afghanistan  AFG  1991                     0.0
# 1  Afghanistan  AFG  1992                     0.0
# 2  Afghanistan  AFG  1993                     0.0
# 3  Afghanistan  AFG  1994                     0.0
# 4  Afghanistan  AFG  1995                     0.0

# %%
obj.merge_map(data=ann_cng, varname='Annual Change In Forest Area')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 obj.merge_map(data=ann_cng, varname='Annual Change In Forest Area')
#
# TypeError: OwidData.merge_map() got an unexpected keyword argument 'data'
